# %% [markdown]
# ![](images/15_04.png)

# %%
pnorm(84, mean = 72, sd = 15.2, lower.tail = FALSE)
# Out:
# [1] 0.2149176

# %%
scores = rnorm(100, mean = 72, sd = 15.2)

# %%
head(scores, 10)
# Out:
#  [1]  80.21109  70.36001  68.69474  75.28014  92.90524  74.40551 100.09379
#  [8]  75.78690  84.30530  80.04820

# %%
hist(scores, main = "Students' Scores", breaks = 30)
# Out:
# Plot with title “Students' Scores”

# %% [markdown]
# ![](images/14_00.png)

# %%
kings = scan("./data/kings.dat.txt", skip=3)

# %%
kings
# Out:
#  [1] 60 43 67 50 56 42 50 65 68 43 65 34 47 34 49 41 13 35 53 56 16 43 69 59 48
# [26] 59 86 55 68 51 33 49 67 77 81 67 71 81 68 70 77 56

# %%
kings_ts = ts(kings, start = 1, end = length(kings), frequency = 1)

# %%
print(kings_ts)
# Out:
# Time Series:
# Start = 1
# End = 42
# Frequency = 1
#  [1] 60 43 67 50 56 42 50 65 68 43 65 34 47 34 49 41 13 35 53 56 16 43 69 59 48
# [26] 59 86 55 68 51 33 49 67 77 81 67 71 81 68 70 77 56

# %%
plot(kings_ts, main = "Age of Death of Successive of Kings of England",
     col = 'blue', xlab = 'Kings', ylab = 'Age')
# Out:
# Plot with title “Age of Death of Successive of Kings of England”

# %% [markdown]
# > **Nhận xét**
# > * Mô hình trên ko có chu trình rõ ràng.
# > * Độ dao động ngẫu nhiên độc lập vs thời gian.

# %% [markdown]
# ![](images/11_13.png)

# %%
data = data.frame(faithful)

# %%
head(data)
# Out:
#   eruptions waiting
# 1 3.600     79
# 2 1.800     54
# 3 3.333     74
# 4 2.283     62
# 5 4.533     85
# 6 2.883     55

# %%
x = data$eruptions
y = data$waiting

# %%
plot(x, y, main = "Faithful",
     xlab = "Eruptions", ylab = "Waiting",
     pch = 19, frame = FALSE, col = 'blue')
lines(lowess(x, y), col = "red", lwd = 3)
# Out:
# Plot with title “Faithful”

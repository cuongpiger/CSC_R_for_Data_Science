# %% [markdown]
# ![](images/11_10.png)

# %%
data = read.table("./data/chol.txt", header = TRUE)

# %%
head(data)
# Out:
#   AGE HEIGHT WEIGHT CHOL SMOKE  BLOOD MORT
# 1 20  176    77     195  nonsmo b     alive
# 2 53  167    56     250  sigare o     dead
# 3 44  170    80     304  sigare a     dead
# 4 37  173    89     178  nonsmo o     alive
# 5 26  170    71     206  sigare o     alive
# 6 41  165    62     284  sigare o     alive

# %%
hist(data$AGE, xlab = "Age", col = "purple", border = "green",
     main = "Chol's ages dataset",
     labels = TRUE, xlim=c(min(data$AGE) - 10, max(data$AGE) + 10))
# Out:
# Plot with title “Chol's ages dataset”
